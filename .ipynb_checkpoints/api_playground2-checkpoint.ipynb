# %%
import requests

url = "https://api-basketball.p.rapidapi.com/games"

querystring = {"date":"2023-02-04"}

headers = {
	"X-RapidAPI-Key": "95d1d0071fmsh61e56ba2bd00280p11af1ajsna4e07526c0e4",
	"X-RapidAPI-Host": "api-basketball.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
import pandas as pd

# %%
pd.DataFrame.from_dict(response.json()['response'])
# Out:
#          id                       date   time   timestamp timezone stage  \
# 0    331468  2023-02-04T00:00:00+00:00  00:00  1675468800      UTC  None
# 1    331469  2023-02-04T00:00:00+00:00  00:00  1675468800      UTC  None
# 2    332112  2023-02-04T00:00:00+00:00  00:00  1675468800      UTC  None
# 3    333446  2023-02-04T00:00:00+00:00  00:00  1675468800      UTC  None
# 4    337527  2023-02-04T00:00:00+00:00  00:00  1675468800      UTC  None
# ..      ...                        ...    ...         ...      ...   ...
# 484  341807  2023-02-04T23:00:00+00:00  23:00  1675551600      UTC  None
# 485  337574  2023-02-04T23:30:00+00:00  23:30  1675553400      UTC  None
# 486  337599  2023-02-04T23:30:00+00:00  23:30  1675553400      UTC  None
# 487  337624  2023-02-04T23:30:00+00:00  23:30  1675553400      UTC  None
# 488  341808  2023-02-04T23:30:00+00:00  23:30  1675553400      UTC  None
#
#      week                                             status  \
# 0    None  {'long': 'Game Finished', 'short': 'FT', 'time...
# 1    None  {'long': 'Game Finished', 'short': 'FT', 'time...
# 2      24  {'long': 'Game Finished', 'short': 'FT', 'time...
# 3    None  {'long': 'Game Finished', 'short': 'FT', 'time...
# 4    None  {'long': 'Game Finished', 'short': 'FT', 'time...
# ..    ...                                                ...
# 484  None  {'long': 'Game Finished', 'short': 'FT', 'time...
# 485  None  {'long': 'Game Finished', 'short': 'FT', 'time...
# 486  None  {'long': 'Game Finished', 'short': 'FT', 'time...
# 487  None  {'long': 'Game Finished', 'short': 'FT', 'time...
# 488  None  {'long': 'Game Finished', 'short': 'FT', 'time...
#
#                                                 league  \
# 0    {'id': 20, 'name': 'NBA - G League', 'type': '...
# 1    {'id': 20, 'name': 'NBA - G League', 'type': '...
# 2    {'id': 18, 'name': 'Liga A', 'type': 'League',...
# 3    {'id': 299, 'name': 'Champions League Americas...
# 4    {'id': 116, 'name': 'NCAA', 'type': 'League', ...
# ..                                                 ...
# 484  {'id': 114, 'name': 'LNB', 'type': 'League', '...
# 485  {'id': 116, 'name': 'NCAA', 'type': 'League', ...
# 486  {'id': 116, 'name': 'NCAA', 'type': 'League', ...
# 487  {'id': 116, 'name': 'NCAA', 'type': 'League', ...
# 488  {'id': 114, 'name': 'LNB', 'type': 'League', '...
#
#                                                country  \
# 0    {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# 1    {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# 2    {'id': 6, 'name': 'Argentina', 'code': 'AR', '...
# 3    {'id': 62, 'name': 'World', 'code': ' ', 'flag...
# 4    {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# ..                                                 ...
# 484  {'id': 53, 'name': 'Chile', 'code': 'CL', 'fla...
# 485  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# 486  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# 487  {'id': 5, 'name': 'USA', 'code': 'US', 'flag':...
# 488  {'id': 53, 'name': 'Chile', 'code': 'CL', 'fla...
#
#                                                  teams  \
# 0    {'home': {'id': 259, 'name': 'Greensboro Swarm...
# 1    {'home': {'id': 3170, 'name': 'Maine Celtics',...
# 2    {'home': {'id': 3115, 'name': 'Union De Santa ...
# 3    {'home': {'id': 295, 'name': 'Quimsa', 'logo':...
# 4    {'home': {'id': 1949, 'name': 'Iona', 'logo': ...
# ..                                                 ...
# 484  {'home': {'id': 1388, 'name': 'Valdivia', 'log...
# 485  {'home': {'id': 2083, 'name': 'Prairie View A&...
# 486  {'home': {'id': 1952, 'name': 'Jackson State',...
# 487  {'home': {'id': 1890, 'name': 'Duke', 'logo': ...
# 488  {'home': {'id': 1447, 'name': 'Espanol de Talc...
#
#                                                 scores
# 0    {'home': {'quarter_1': 42, 'quarter_2': 31, 'q...
# 1    {'home': {'quarter_1': 25, 'quarter_2': 14, 'q...
# 2    {'home': {'quarter_1': 17, 'quarter_2': 25, 'q...
# 3    {'home': {'quarter_1': 28, 'quarter_2': 12, 'q...
# 4    {'home': {'quarter_1': 0, 'quarter_2': 48, 'qu...
# ..                                                 ...
# 484  {'home': {'quarter_1': 22, 'quarter_2': 20, 'q...
# 485  {'home': {'quarter_1': 0, 'quarter_2': 33, 'qu...
# 486  {'home': {'quarter_1': 0, 'quarter_2': 40, 'qu...
# 487  {'home': {'quarter_1': 0, 'quarter_2': 33, 'qu...
# 488  {'home': {'quarter_1': 29, 'quarter_2': 23, 'q...
#
# [489 rows x 12 columns]

# %%
pd.set_option('display.max_columns', None)

# %%
basketball_data: pd.DataFrame = pd.json_normalize(response.json()['response'], sep='_')

# %%
basketball_data.columns
# Out:
# Index(['id', 'date', 'time', 'timestamp', 'timezone', 'stage', 'week',
#        'status_long', 'status_short', 'status_timer', 'league_id',
#        'league_name', 'league_type', 'league_season', 'league_logo',
#        'country_id', 'country_name', 'country_code', 'country_flag',
#        'teams_home_id', 'teams_home_name', 'teams_home_logo', 'teams_away_id',
#        'teams_away_name', 'teams_away_logo', 'scores_home_quarter_1',
#        'scores_home_quarter_2', 'scores_home_quarter_3',
#        'scores_home_quarter_4', 'scores_home_over_time', 'scores_home_total',
#        'scores_away_quarter_1', 'scores_away_quarter_2',
#        'scores_away_quarter_3', 'scores_away_quarter_4',
#        'scores_away_over_time', 'scores_away_total'],
#       dtype='object')

# %%
basketball_data['scores_home_over_time'].value_counts()
# Out:
# 10.0    4
# 14.0    3
# 7.0     2
# 4.0     1
# 28.0    1
# 6.0     1
# 24.0    1
# 11.0    1
# 9.0     1
# 8.0     1
# Name: scores_home_over_time, dtype: int64

# %%
basketball_data.head()
# Out:
#        id                       date   time   timestamp timezone stage  week  \
# 0  331468  2023-02-04T00:00:00+00:00  00:00  1675468800      UTC  None  None
# 1  331469  2023-02-04T00:00:00+00:00  00:00  1675468800      UTC  None  None
# 2  332112  2023-02-04T00:00:00+00:00  00:00  1675468800      UTC  None    24
# 3  333446  2023-02-04T00:00:00+00:00  00:00  1675468800      UTC  None  None
# 4  337527  2023-02-04T00:00:00+00:00  00:00  1675468800      UTC  None  None
#
#      status_long status_short status_timer  league_id  \
# 0  Game Finished           FT         None         20
# 1  Game Finished           FT         None         20
# 2  Game Finished           FT         None         18
# 3  Game Finished           FT         None        299
# 4  Game Finished           FT         None        116
#
#                  league_name league_type league_season  \
# 0             NBA - G League      League     2022-2023
# 1             NBA - G League      League     2022-2023
# 2                     Liga A      League     2022-2023
# 3  Champions League Americas         cup     2022-2023
# 4                       NCAA      League     2022-2023
#
#                                          league_logo  country_id country_name  \
# 0  https://media-1.api-sports.io/basketball/leagu...           5          USA
# 1  https://media-1.api-sports.io/basketball/leagu...           5          USA
# 2  https://media-2.api-sports.io/basketball/leagu...           6    Argentina
# 3  https://media-3.api-sports.io/basketball/leagu...          62        World
# 4  https://media-1.api-sports.io/basketball/leagu...           5          USA
#
#   country_code                                country_flag  teams_home_id  \
# 0           US  https://media-3.api-sports.io/flags/us.svg            259
# 1           US  https://media-1.api-sports.io/flags/us.svg           3170
# 2           AR  https://media-3.api-sports.io/flags/ar.svg           3115
# 3                https://media-2.api-sports.io/flags/ .svg            295
# 4           US  https://media-3.api-sports.io/flags/us.svg           1949
#
#      teams_home_name                                    teams_home_logo  \
# 0   Greensboro Swarm  https://media-1.api-sports.io/basketball/teams...
# 1      Maine Celtics  https://media-3.api-sports.io/basketball/teams...
# 2  Union De Santa Fe  https://media-2.api-sports.io/basketball/teams...
# 3             Quimsa  https://media-2.api-sports.io/basketball/teams...
# 4               Iona  https://media-1.api-sports.io/basketball/teams...
#
#    teams_away_id        teams_away_name  \
# 0           3403      Grand Rapids Gold
# 1            254  College Park Skyhawks
# 2            297            San Lorenzo
# 3           2990                  Bigua
# 4           2020       Mount St. Mary's
#
#                                      teams_away_logo  scores_home_quarter_1  \
# 0  https://media-1.api-sports.io/basketball/teams...                   42.0
# 1  https://media-2.api-sports.io/basketball/teams...                   25.0
# 2  https://media-1.api-sports.io/basketball/teams...                   17.0
# 3  https://media-2.api-sports.io/basketball/teams...                   28.0
# 4  https://media-2.api-sports.io/basketball/teams...                    0.0
#
#    scores_home_quarter_2  scores_home_quarter_3  scores_home_quarter_4  \
# 0                   31.0                   24.0                   26.0
# 1                   14.0                   35.0                   22.0
# 2                   25.0                   23.0                   25.0
# 3                   12.0                   21.0                   27.0
# 4                   48.0                    0.0                   33.0
#
#    scores_home_over_time  scores_home_total  scores_away_quarter_1  \
# 0                    NaN              123.0                   18.0
# 1                    NaN               96.0                   25.0
# 2                    NaN               90.0                   20.0
# 3                    NaN               88.0                   11.0
# 4                    NaN               81.0                    0.0
#
#    scores_away_quarter_2  scores_away_quarter_3  scores_away_quarter_4  \
# 0                   29.0                   37.0                   23.0
# 1                   35.0                   26.0                   28.0
# 2                   18.0                   19.0                   22.0
# 3                   24.0                   17.0                   15.0
# 4                   18.0                    0.0                   33.0
#
#    scores_away_over_time  scores_away_total
# 0                    NaN              107.0
# 1                    NaN              114.0
# 2                    NaN               79.0
# 3                    NaN               67.0
# 4                    NaN               51.0

# %%
basketball_data.dtypes
# Out:
# id                         int64
# date                      object
# time                      object
# timestamp                  int64
# timezone                  object
# stage                     object
# week                      object
# status_long               object
# status_short              object
# status_timer              object
# league_id                  int64
# league_name               object
# league_type               object
# league_season             object
# league_logo               object
# country_id                 int64
# country_name              object
# country_code              object
# country_flag              object
# teams_home_id              int64
# teams_home_name           object
# teams_home_logo           object
# teams_away_id              int64
# teams_away_name           object
# teams_away_logo           object
# scores_home_quarter_1    float64
# scores_home_quarter_2    float64
# scores_home_quarter_3    float64
# scores_home_quarter_4    float64
# scores_home_over_time    float64
# scores_home_total        float64
# scores_away_quarter_1    float64
# scores_away_quarter_2    float64
# scores_away_quarter_3    float64
# scores_away_quarter_4    float64
# scores_away_over_time    float64
# scores_away_total        float64
# dtype: object

# %%
len(basketball_data.columns)
# Out:
# 37

# %%
import boto3

# %%
def get_data_from_api():
    url = "https://api-basketball.p.rapidapi.com/games"

    querystring = {"date":"2023-02-04"}

    headers = {
        "X-RapidAPI-Key": "95d1d0071fmsh61e56ba2bd00280p11af1ajsna4e07526c0e4",
        "X-RapidAPI-Host": "api-basketball.p.rapidapi.com"
    }

    response = requests.request("GET", url, headers=headers, params=querystring)
    json_response = response.json()

    api_data = json.dumps(json_response, indent=4)

    s3 = boto3.resource(
        service_name='s3',
        region_name='us-east-1',
        aws_access_key_id='AKIA4VNTOKW7LDEWF4VW',
        aws_secret_access_key='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',
    )

    s3_bucket = s3.Bucket(name='cs779')

    s3_bucket.put_object(
        Key='basketball_games.json',
        Body=api_data
    )
    
def upload_to_azure_sql():
    conn = pyodbc.connect(
        'DRIVER={ODBC Driver 18 for SQL Server};Server=tcp:cs779-server.database.windows.net,1433;Database=cs779;Uid=epoch;Pwd=**********;Encrypt=yes;TrustServerCertificate=no;Connection Timeout=30;'
        )
    cursor = conn.cursor()

    s3 = boto3.resource(
        service_name='s3',
        region_name='us-east-1',
        aws_access_key_id='AKIA4VNTOKW7LDEWF4VW',
        aws_secret_access_key='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',
    )

    s3_object = s3.Bucket('cs779').Object('basketball_games.json').get()['Body'].read()
    s3_json = json.loads(s3_object)

    df: pd.DataFrame = pd.json_normalize(s3_json['response'], sep='_')

    for row in df.itertuples():
        cursor.execute('''
                    INSERT INTO basketball_games (
                        id,
                        date,
                        time,
                        timestamp,
                        timezone,
                        stage,
                        week,
                        status_long,
                        status_short,
                        status_timer,
                        league_id,
                        league_name,
                        league_type,
                        league_season,
                        league_logo,
                        country_id,
                        country_name,
                        country_code,
                        country_flag,
                        teams_home_id,
                        teams_home_name,
                        teams_home_logo,
                        teams_away_id,
                        teams_away_name,
                        teams_away_logo,
                        scores_home_quarter_1,
                        scores_home_quarter_2,
                        scores_home_quarter_3,
                        scores_home_quarter_4,
                        scores_home_over_time,
                        scores_home_total,
                        scores_away_quarter_1,
                        scores_away_quarter_2,
                        scores_away_quarter_3,
                        scores_away_quarter_4,
                        scores_away_over_time,
                        scores_away_total
                        )
                    VALUES (
                    ?,?,?,?,?,?,?,?,?,?,?,?,
                    ?,?,?,?,?,?,?,?,?,?,?,?,
                    ?,?,?,?,?,?,?,?,?,?,?,?,
                    ?,
                    )
                    ''',
                    row.id,
                    row.date,
                    row.time,
                    row.timestamp,
                    row.timezone,
                    row.stage,
                    row.week,
                    row.status_long,
                    row.status_short,
                    row.status_timer,
                    row.league_id,
                    row.league_name,
                    row.league_type,
                    row.league_season,
                    row.league_logo,
                    row.country_id,
                    row.country_name,
                    row.country_code,
                    row.country_flag,
                    row.teams_home_id,
                    row.teams_home_name,
                    row.teams_home_logo,
                    row.teams_away_id,
                    row.teams_away_name,
                    row.teams_away_logo,
                    row.scores_home_quarter_1,
                    row.scores_home_quarter_2,
                    row.scores_home_quarter_3,
                    row.scores_home_quarter_4,
                    row.scores_home_over_time,
                    row.scores_home_total,
                    row.scores_away_quarter_1,
                    row.scores_away_quarter_2,
                    row.scores_away_quarter_3,
                    row.scores_away_quarter_4,
                    row.scores_away_over_time,
                    row.scores_away_total
                    )
    conn.commit()

# %%
get_data_from_api()

# %%
import pyodbc

# %%
upload_to_azure_sql()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 upload_to_azure_sql()
#
# Cell In[39], line 31, in upload_to_azure_sql()
#      30 def upload_to_azure_sql():
# ---> 31     conn = pyodbc.connect(
#      32         'DRIVER={ODBC Driver 18 for SQL Server};Server=tcp:cs779-server.database.windows.net,1433;Database=cs779;Uid=epoch;Pwd=**********;Encrypt=yes;TrustServerCertificate=no;Connection Timeout=30;'
#      33         )
#      34     cursor = conn.cursor()
#      36     s3 = boto3.resource(
#      37         service_name='s3',
#      38         region_name='us-east-1',
#      39         aws_access_key_id='AKIA4VNTOKW7LDEWF4VW',
#      40         aws_secret_access_key='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',
#      41     )
#
# Error: ('01000', "[01000] [unixODBC][Driver Manager]Can't open lib 'ODBC Driver 18 for SQL Server' : file not found (0) (SQLDriverConnect)")

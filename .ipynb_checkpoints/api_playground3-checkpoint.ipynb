# %%
import requests
import pandas as pd
import time

# %%
url = "https://api-football-v1.p.rapidapi.com/v3/leagues"

querystring = {"country":"England"}

headers = {
	"X-RapidAPI-Key": "95d1d0071fmsh61e56ba2bd00280p11af1ajsna4e07526c0e4",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
json_response = response.json()['response']
df_league_raw = pd.json_normalize(json_response)
df_league = df_league_raw[['league.id', 'league.name', 'league.type']]
df_league.head()
# Out:
#    league.id     league.name league.type
# 0         39  Premier League      League
# 1         40    Championship      League
# 2         46      EFL Trophy         Cup
# 3         45          FA Cup         Cup
# 4         47       FA Trophy         Cup

# %%
league_ids: set = set(df_league['league.id'])
teams_info: list = []
for league in league_ids:
    time.sleep(2)
    url = "https://api-football-v1.p.rapidapi.com/v3/teams"

    querystring = {"league":league,"season":"2022"}

    headers = {
        "X-RapidAPI-Key": "95d1d0071fmsh61e56ba2bd00280p11af1ajsna4e07526c0e4",
        "X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
    }

    response = requests.request("GET", url, headers=headers, params=querystring)
    teams_info.extend(response.json()['response'])

# %%
len(teams_info)
# Out:
# 1907

# %%
teams_info
# Out:
# [{'team': {'id': 40,
#    'name': 'Liverpool',
#    'code': 'LIV',
#    'country': 'England',
#    'founded': 1892,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/40.png'},
#   'venue': {'id': 550,
#    'name': 'Anfield',
#    'address': 'Anfield Road',
#    'city': 'Liverpool',
#    'capacity': 55212,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/550.png'}},
#  {'team': {'id': 50,
#    'name': 'Manchester City',
#    'code': 'MAC',
#    'country': 'England',
#    'founded': 1880,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/50.png'},
#   'venue': {'id': 555,
#    'name': 'Etihad Stadium',
#    'address': 'Rowsley Street',
#    'city': 'Manchester',
#    'capacity': 55097,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/555.png'}},
#  {'team': {'id': 4682,
#    'name': 'Hitchin Town',
#    'code': 'HIT',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/4682.png'},
#   'venue': {'id': 3531,
#    'name': 'Top Field',
#    'address': 'Fishponds Road',
#    'city': 'Hitchin, Hertfordshire',
#    'capacity': 4000,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/3531.png'}},
#  {'team': {'id': 4710,
#    'name': 'Stourbridge',
#    'code': 'STO',
#    'country': 'England',
#    'founded': 1876,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/4710.png'},
#   'venue': {'id': 3559,
#    'name': 'War Memorial Athletic Ground',
#    'address': 'High Street, Amblecote',
#    'city': 'Stourbridge, West Midlands',
#    'capacity': 3550,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/3559.png'}},
#  {'team': {'id': 7236,
#    'name': 'Ilkeston Town',
#    'code': 'ILK',
#    'country': 'England',
#    'founded': 2017,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7236.png'},
#   'venue': {'id': 5237,
#    'name': 'New Manor Ground',
#    'address': 'Awsworth Road',
#    'city': 'Ilkeston, Derbyshire',
#    'capacity': 3500,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5237.png'}},
#  {'team': {'id': 7616,
#    'name': 'Bedford Town',
#    'code': 'BED',
#    'country': 'England',
#    'founded': 1908,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7616.png'},
#   'venue': {'id': 5483,
#    'name': 'The New Eyrie',
#    'address': 'Meadow Lane',
#    'city': 'Cardington, Bedfordshire',
#    'capacity': 4000,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5483.png'}},
#  {'team': {'id': 7691,
#    'name': 'AFC Rushden & Diamonds',
#    'code': None,
#    'country': 'England',
#    'founded': 2011,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7691.png'},
#   'venue': {'id': 5553,
#    'name': 'Hayden Road',
#    'address': 'Hayden Road',
#    'city': 'Rushden, Northamptonshire',
#    'capacity': 1500,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5553.png'}},
#  {'team': {'id': 7692,
#    'name': 'Alvechurch',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7692.png'},
#   'venue': {'id': 5554,
#    'name': 'Lye Meadow',
#    'address': 'Redditch Road',
#    'city': 'Alvechurch, Worcestershire',
#    'capacity': 3000,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/5554.png'}},
#  {'team': {'id': 7697,
#    'name': 'Barwell',
#    'code': 'BRW',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7697.png'},
#   'venue': {'id': 5559,
#    'name': 'Kirkby Road',
#    'address': 'Kirkby Road',
#    'city': 'Barwell, Leicestershire',
#    'capacity': 2500,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5559.png'}},
#  {'team': {'id': 7698,
#    'name': 'Basford United',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7698.png'},
#   'venue': {'id': 5560,
#    'name': 'Greenwich Avenue',
#    'address': 'Greenwich Avenue, Basford',
#    'city': 'Nottingham, Nottinghamshire',
#    'capacity': 1000,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5560.png'}},
#  {'team': {'id': 7705,
#    'name': 'Bromsgrove Sporting',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7705.png'},
#   'venue': {'id': 5566,
#    'name': 'The Victoria Ground',
#    'address': 'Birmingham Road',
#    'city': 'Bromsgrove, Worcestershire',
#    'capacity': 4893,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5566.png'}},
#  {'team': {'id': 7709,
#    'name': 'Coalville Town',
#    'code': 'COA',
#    'country': 'England',
#    'founded': 1926,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7709.png'},
#   'venue': {'id': 5569,
#    'name': 'Owen Street Sports Ground',
#    'address': 'Owen Street',
#    'city': 'Coalville, Leicestershire',
#    'capacity': 1500,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5569.png'}},
#  {'team': {'id': 7721,
#    'name': 'Hednesford Town',
#    'code': 'HED',
#    'country': 'England',
#    'founded': 1880,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7721.png'},
#   'venue': {'id': 5580,
#    'name': 'Keys Park',
#    'address': 'Keys Park Road',
#    'city': 'Hednesford, Staffordshire',
#    'capacity': 6500,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5580.png'}},
#  {'team': {'id': 7724,
#    'name': 'Kings Langley',
#    'code': None,
#    'country': 'England',
#    'founded': 1886,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7724.png'},
#   'venue': {'id': 5583,
#    'name': 'The Orbital Fasteners Stadium',
#    'address': 'Hempstead Road',
#    'city': 'Kings Langley, Hertfordshire',
#    'capacity': 1000,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5583.png'}},
#  {'team': {'id': 7727,
#    'name': 'Leiston',
#    'code': 'LEI',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7727.png'},
#   'venue': {'id': 5585,
#    'name': 'Victory Road',
#    'address': 'Victory Road',
#    'city': 'Leiston, Suffolk',
#    'capacity': 2500,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5585.png'}},
#  {'team': {'id': 7733,
#    'name': 'Mickleover Sports',
#    'code': None,
#    'country': 'England',
#    'founded': 1948,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7733.png'},
#   'venue': {'id': 5591,
#    'name': 'Don Amott Leisure Group Arena',
#    'address': 'Station Road',
#    'city': 'Derby, Derbyshire',
#    'capacity': 1500,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5591.png'}},
#  {'team': {'id': 7735,
#    'name': 'Needham Market',
#    'code': None,
#    'country': 'England',
#    'founded': 1919,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7735.png'},
#   'venue': {'id': 5593,
#    'name': 'Bloomfields',
#    'address': 'Quinton Road',
#    'city': 'Needham Market, Suffolk',
#    'capacity': 4000,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5593.png'}},
#  {'team': {'id': 7741,
#    'name': 'Redditch United',
#    'code': 'RED',
#    'country': 'England',
#    'founded': 1891,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7741.png'},
#   'venue': {'id': 5599,
#    'name': 'The Valley Stadium',
#    'address': 'Bromsgrove Road, Batchley',
#    'city': 'Redditch, Worcestershire',
#    'capacity': 5000,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5599.png'}},
#  {'team': {'id': 7742,
#    'name': 'Royston Town',
#    'code': None,
#    'country': 'England',
#    'founded': 1872,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7742.png'},
#   'venue': {'id': 10662,
#    'name': 'Garden Walk',
#    'address': 'Garden Walk',
#    'city': 'Royston, Hertfordshire',
#    'capacity': 4000,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/10662.png'}},
#  {'team': {'id': 7743,
#    'name': 'Rushall Olympic',
#    'code': 'RUS',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7743.png'},
#   'venue': {'id': 5601,
#    'name': 'Dales Lane',
#    'address': 'Daw End, Bosty Lane, Rushall',
#    'city': 'Walsall, West Midlands',
#    'capacity': 1400,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5601.png'}},
#  {'team': {'id': 7747,
#    'name': 'St Ives Town',
#    'code': 'IVE',
#    'country': 'England',
#    'founded': 1887,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7747.png'},
#   'venue': {'id': 10663,
#    'name': 'Westwood Road',
#    'address': 'Westwood Road',
#    'city': 'St Ives, Cambridgeshire',
#    'capacity': 2000,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/10663.png'}},
#  {'team': {'id': 7750,
#    'name': 'Stratford Town',
#    'code': None,
#    'country': 'England',
#    'founded': 1941,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7750.png'},
#   'venue': {'id': 5608,
#    'name': 'The Arden Garages Stadium',
#    'address': 'Knights Lane, Tiddington',
#    'city': 'Stratford-upon-Avon, Warwickshire',
#    'capacity': 2800,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5608.png'}},
#  {'team': {'id': 7752,
#    'name': 'Tamworth',
#    'code': 'TAM',
#    'country': 'England',
#    'founded': 1933,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7752.png'},
#   'venue': {'id': 5610,
#    'name': 'The Lamb Ground',
#    'address': 'Meadow Street, Kettlebrook',
#    'city': 'Tamworth, Staffordshire',
#    'capacity': 4065,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5610.png'}},
#  {'team': {'id': 10159,
#    'name': 'Nuneaton Town',
#    'code': 'NUN',
#    'country': 'England',
#    'founded': 2008,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/10159.png'},
#   'venue': {'id': 10665,
#    'name': 'Liberty Way',
#    'address': 'Liberty Way',
#    'city': 'Nuneaton, Warwickshire',
#    'capacity': 6250,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/10665.png'}},
#  {'team': {'id': 7247,
#    'name': 'Pontefract Collieries',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7247.png'},
#   'venue': {'id': 12609,
#    'name': 'The Regional Electrical Service Ltd Stadium',
#    'address': 'Skinner Lane',
#    'city': 'Pontefract, West Yorkshire',
#    'capacity': 1429,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/12609.png'}},
#  {'team': {'id': 7252,
#    'name': 'Stocksbridge Park Steels',
#    'code': 'STO',
#    'country': 'England',
#    'founded': 1986,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7252.png'},
#   'venue': {'id': 5252,
#    'name': 'Bracken Moor',
#    'address': 'Bracken Moor Lane',
#    'city': 'Stocksbridge, South Yorkshire',
#    'capacity': 3500,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5252.png'}},
#  {'team': {'id': 7266,
#    'name': 'Worksop Town',
#    'code': None,
#    'country': 'England',
#    'founded': 1861,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7266.png'},
#   'venue': {'id': 10657,
#    'name': 'Sandy Lane',
#    'address': 'Babbage Way / Sandy Lane',
#    'city': 'Worksop, Nottinghamshire',
#    'capacity': 3200,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/10657.png'}},
#  {'team': {'id': 7620,
#    'name': 'Brighouse Town',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7620.png'},
#   'venue': {'id': 5487,
#    'name': 'The Yorkshire Payments Stadium',
#    'address': 'St Giles Road',
#    'city': 'Brighouse, West Yorkshire',
#    'capacity': 800,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/5487.png'}},
#  {'team': {'id': 7624,
#    'name': 'Carlton Town',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7624.png'},
#   'venue': {'id': 10615,
#    'name': 'Bill Stokeld Stadium',
#    'address': 'Stoke Lane, Gedling, Carlton',
#    'city': 'Nottingham, East Midlands',
#    'capacity': 600,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/10615.png'}},
#  {'team': {'id': 7631,
#    'name': 'Cleethorpes Town',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7631.png'},
#   'venue': {'id': 12045,
#    'name': 'The myenergi Stadium',
#    'address': 'Clee Road',
#    'city': 'Grimsby, Lincolnshire',
#    'capacity': 1000,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/12045.png'}},
#  {'team': {'id': 7639,
#    'name': 'Dunston UTS',
#    'code': None,
#    'country': 'England',
#    'founded': 1975,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7639.png'},
#   'venue': {'id': 5506,
#    'name': 'UTS Stadium',
#    'address': 'Wellington Road, Dunston',
#    'city': 'Gateshead, Tyne and Wear',
#    'capacity': 2500,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5506.png'}},
#  {'team': {'id': 7652,
#    'name': 'Lincoln United',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7652.png'},
#   'venue': {'id': 5519,
#    'name': 'Sun Hat Villas & Resorts Stadium',
#    'address': 'Ashby Avenue',
#    'city': 'Lincoln, Lincolnshire',
#    'capacity': 2200,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/5519.png'}},
#  {'team': {'id': 7662,
#    'name': 'Ossett United',
#    'code': None,
#    'country': 'England',
#    'founded': 2018,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7662.png'},
#   'venue': {'id': 10627,
#    'name': 'Ingfield Stadium',
#    'address': 'Prospect Road',
#    'city': 'Ossett, West Yorkshire',
#    'capacity': 2000,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/10627.png'}},
#  {'team': {'id': 7667,
#    'name': 'Sheffield',
#    'code': 'SHE',
#    'country': 'England',
#    'founded': 1857,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7667.png'},
#   'venue': {'id': 5534,
#    'name': 'The Coach and Horses Ground',
#    'address': 'Sheffield Road',
#    'city': 'Dronfield, North East Derbyshire',
#    'capacity': 2089,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5534.png'}},
#  {'team': {'id': 7674,
#    'name': 'Tadcaster Albion',
#    'code': None,
#    'country': 'England',
#    'founded': 1892,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7674.png'},
#   'venue': {'id': 10628,
#    'name': 'i2i Stadium',
#    'address': 'Ings Lane',
#    'city': 'Tadcaster, North Yorkshire',
#    'capacity': 1500,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/10628.png'}},
#  {'team': {'id': 7718,
#    'name': 'Grantham Town',
#    'code': 'GRA',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7718.png'},
#   'venue': {'id': 5577,
#    'name': 'South Kesteven Stadium',
#    'address': 'Trent Road',
#    'city': 'Grantham, Lincolnshire',
#    'capacity': 7500,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/5577.png'}},
#  {'team': {'id': 8719,
#    'name': 'Bridlington Town',
#    'code': None,
#    'country': 'England',
#    'founded': 1918,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/8719.png'},
#   'venue': {'id': 12168,
#    'name': 'The Neil Hudgell Law Stadium',
#    'address': 'Queensgate',
#    'city': 'Bridlington, East Yorkshire',
#    'capacity': 2740,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/12168.png'}},
#  {'team': {'id': 8752,
#    'name': 'Consett',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/8752.png'},
#   'venue': {'id': 11724,
#    'name': 'Belle Vue Park',
#    'address': 'Delves Lane',
#    'city': 'Consett, County Durham',
#    'capacity': 4000,
#    'surface': 'artificial turf',
#    'image': 'https://media-2.api-sports.io/football/venues/11724.png'}},
#  {'team': {'id': 8797,
#    'name': 'Grimsby Borough',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/8797.png'},
#   'venue': {'id': 11748,
#    'name': 'Bradley Community Stadium',
#    'address': 'Bradley Road',
#    'city': 'Grimsby, Lincolnshire',
#    'capacity': 1000,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/11748.png'}},
#  {'team': {'id': 8822,
#    'name': 'Hebburn Town',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/8822.png'},
#   'venue': {'id': 11764,
#    'name': 'The Energy Check Sports Ground',
#    'address': 'North Drive / Victoria Road West',
#    'city': 'Hebburn, Tyne and Wear',
#    'capacity': 1500,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/11764.png'}},
#  {'team': {'id': 8856,
#    'name': 'Long Eaton United',
#    'code': None,
#    'country': 'England',
#    'founded': 1956,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/8856.png'},
#   'venue': {'id': 11783,
#    'name': 'Grange Park',
#    'address': 'Station Road',
#    'city': 'Long Eaton, Derbyshire',
#    'capacity': 1500,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/11783.png'}},
#  {'team': {'id': 8882,
#    'name': 'North Shields',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/8882.png'},
#   'venue': {'id': 11798,
#    'name': 'Daren Persson Stadium',
#    'address': 'West Percy Road',
#    'city': 'North Shields, Tyne and Wear',
#    'capacity': 1000,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/11798.png'}},
#  {'team': {'id': 8932,
#    'name': 'Shildon AFC',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/8932.png'},
#   'venue': {'id': 11827,
#    'name': 'Dean Street',
#    'address': 'Dean Street',
#    'city': 'Shildon, County Durham',
#    'capacity': 4700,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/11827.png'}},
#  {'team': {'id': 8953,
#    'name': 'Stockton Town',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/8953.png'},
#   'venue': {'id': 11840,
#    'name': 'The Map Group UK Stadium',
#    'address': 'Bishopton Road West',
#    'city': 'Stockton-on-Tees',
#    'capacity': 1800,
#    'surface': 'artificial turf',
#    'image': 'https://media-3.api-sports.io/football/venues/11840.png'}},
#  {'team': {'id': 7208,
#    'name': 'Aylesbury United',
#    'code': None,
#    'country': 'England',
#    'founded': 1897,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7208.png'},
#   'venue': {'id': 3551,
#    'name': 'The Meadow',
#    'address': 'Amy Lane',
#    'city': 'Chesham, Buckinghamshire',
#    'capacity': 2000,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/3551.png'}},
#  {'team': {'id': 7214,
#    'name': 'Berkhamsted',
#    'code': None,
#    'country': 'England',
#    'founded': 2009,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7214.png'},
#   'venue': {'id': 5217,
#    'name': 'Broadwater',
#    'address': 'Broadwater',
#    'city': 'Berkhamsted, Hertfordshire',
#    'capacity': 2500,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5217.png'}},
#  {'team': {'id': 7222,
#    'name': 'Didcot Town',
#    'code': None,
#    'country': 'England',
#    'founded': 1907,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7222.png'},
#   'venue': {'id': 5225,
#    'name': 'NPower Loop Meadow Stadium',
#    'address': 'Bowmont Water',
#    'city': 'Didcot, Oxfordshire',
#    'capacity': 3000,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5225.png'}},
#  {'team': {'id': 7225,
#    'name': 'FC Romania',
#    'code': None,
#    'country': 'England',
#    'founded': 2006,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7225.png'},
#   'venue': {'id': 5228,
#    'name': 'The Stadium Cheshunt',
#    'address': 'Theobalds Lane',
#    'city': 'Cheshunt, Hertfordshire',
#    'capacity': 3000,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/5228.png'}},
#  {'team': {'id': 7233,
#    'name': 'Highworth Town',
#    'code': None,
#    'country': 'England',
#    'founded': 1894,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7233.png'},
#   'venue': {'id': 5235,
#    'name': 'Save On Tyres Stadium',
#    'address': None,
#    'city': 'Highworth, Wiltshire',
#    'capacity': 1000,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5235.png'}},
#  {'team': {'id': 7259,
#    'name': 'Waltham Abbey',
#    'code': None,
#    'country': 'England',
#    'founded': 1944,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7259.png'},
#   'venue': {'id': 5259,
#    'name': 'Capershotts',
#    'address': 'Sewardstone',
#    'city': 'Waltham Abbey, Essex',
#    'capacity': 3500,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/5259.png'}},
#  {'team': {'id': 7610,
#    'name': 'AFC Dunstable',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7610.png'},
#   'venue': {'id': 5477,
#    'name': 'Creasey Park Community Football Centre',
#    'address': 'Creasey Park Drive',
#    'city': 'Dunstable, Bedfordshire',
#    'capacity': 3200,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/5477.png'}},
#  {'team': {'id': 7611,
#    'name': 'AFC Kempston Rovers',
#    'code': None,
#    'country': 'England',
#    'founded': 1884,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7611.png'},
#   'venue': {'id': 5478,
#    'name': 'Hillgrounds Leisure',
#    'address': 'Hillgrounds Leisure, Hillgrounds Road',
#    'city': 'Kempston, Bedfordshire',
#    'capacity': 2000,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5478.png'}},
#  {'team': {'id': 7614,
#    'name': 'Barton Rovers',
#    'code': None,
#    'country': 'England',
#    'founded': 1982,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7614.png'},
#   'venue': {'id': 5481,
#    'name': 'Sharpenhoe Road',
#    'address': 'Sharpenhoe Road',
#    'city': 'Barton-Le-Clay, Bedfordshire',
#    'capacity': 4000,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/5481.png'}},
#  {'team': {'id': 7618,
#    'name': 'Biggleswade',
#    'code': None,
#    'country': 'England',
#    'founded': 2016,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7618.png'},
#   'venue': {'id': 5485,
#    'name': 'The Carlsberg Stadium',
#    'address': 'Langford Road',
#    'city': 'Biggleswade, Bedfordshire',
#    'capacity': 3000,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5485.png'}},
#  {'team': {'id': 7629,
#    'name': 'Cirencester Town',
#    'code': None,
#    'country': 'England',
#    'founded': 1889,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7629.png'},
#   'venue': {'id': 5496,
#    'name': 'The Corinium Stadium',
#    'address': 'Kingshill Lane',
#    'city': 'Cirencester, Gloucestershire',
#    'capacity': 4500,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5496.png'}},
#  {'team': {'id': 7646,
#    'name': 'Harlow Town',
#    'code': None,
#    'country': 'England',
#    'founded': 1879,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7646.png'},
#   'venue': {'id': 11678,
#    'name': "McCulloch's Stadium",
#    'address': 'Roydon Road / Off Elizabeth Way',
#    'city': 'Harlow, Essex',
#    'capacity': 3500,
#    'surface': 'artificial turf',
#    'image': 'https://media-3.api-sports.io/football/venues/11678.png'}},
#  {'team': {'id': 7648,
#    'name': 'Hertford Town',
#    'code': None,
#    'country': 'England',
#    'founded': 1908,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7648.png'},
#   'venue': {'id': 5515,
#    'name': 'Hertingfordbury Park',
#    'address': 'West Street',
#    'city': 'Hertford, Hertfordshire',
#    'capacity': 6500,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/5515.png'}},
#  {'team': {'id': 7650,
#    'name': 'Kidlington',
#    'code': None,
#    'country': 'England',
#    'founded': 1908,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7650.png'},
#   'venue': {'id': 5517,
#    'name': 'Yarnton Road',
#    'address': 'Yarnton Road',
#    'city': 'Kidlington, Oxfordshire',
#    'capacity': 1500,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/5517.png'}},
#  {'team': {'id': 7675,
#    'name': 'Thame United',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7675.png'},
#   'venue': {'id': 5542,
#    'name': 'ASM Stadium',
#    'address': 'Tythrop Way (Kingsey Road)',
#    'city': 'Thame, Oxfordshire',
#    'capacity': 2500,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/5542.png'}},
#  {'team': {'id': 7678,
#    'name': 'Ware',
#    'code': None,
#    'country': 'England',
#    'founded': 1892,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7678.png'},
#   'venue': {'id': 5545,
#    'name': 'Wodson Park',
#    'address': 'Wadesmill Road',
#    'city': 'Ware, Hertfordshire',
#    'capacity': 3300,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5545.png'}},
#  {'team': {'id': 7679,
#    'name': 'Welwyn Garden City',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7679.png'},
#   'venue': {'id': 10629,
#    'name': 'Herns Way',
#    'address': 'Herns Way, Panshanger',
#    'city': 'Welwyn Garden City, Hertfordshire',
#    'capacity': 1000,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/10629.png'}},
#  {'team': {'id': 7700,
#    'name': 'Biggleswade Town',
#    'code': 'BIG',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7700.png'},
#   'venue': {'id': 5485,
#    'name': 'The Carlsberg Stadium',
#    'address': 'Langford Road',
#    'city': 'Biggleswade, Bedfordshire',
#    'capacity': 3000,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5485.png'}},
#  {'team': {'id': 8802,
#    'name': 'Hadley',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/8802.png'},
#   'venue': {'id': 11751,
#    'name': 'Hadley Sports Ground',
#    'address': 'Brickfield Lane, Arkley, Barnet',
#    'city': 'London',
#    'capacity': 1000,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/11751.png'}},
#  {'team': {'id': 8985,
#    'name': 'Walthamstow',
#    'code': None,
#    'country': 'England',
#    'founded': 1964,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/8985.png'},
#   'venue': {'id': 11857,
#    'name': 'Wadham Lodge Stadium',
#    'address': 'Kitchener Road, Walthamstow',
#    'city': 'London',
#    'capacity': 4000,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/11857.png'}},
#  {'team': {'id': 33,
#    'name': 'Manchester United',
#    'code': 'MUN',
#    'country': 'England',
#    'founded': 1878,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/33.png'},
#   'venue': {'id': 556,
#    'name': 'Old Trafford',
#    'address': 'Sir Matt Busby Way',
#    'city': 'Manchester',
#    'capacity': 76212,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/556.png'}},
#  {'team': {'id': 34,
#    'name': 'Newcastle',
#    'code': 'NEW',
#    'country': 'England',
#    'founded': 1892,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/34.png'},
#   'venue': {'id': 562,
#    'name': "St. James' Park",
#    'address': 'St. James&apos; Street',
#    'city': 'Newcastle upon Tyne',
#    'capacity': 52389,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/562.png'}},
#  {'team': {'id': 35,
#    'name': 'Bournemouth',
#    'code': 'BOU',
#    'country': 'England',
#    'founded': 1899,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/35.png'},
#   'venue': {'id': 504,
#    'name': 'Vitality Stadium',
#    'address': 'Dean Court, Kings Park',
#    'city': 'Bournemouth, Dorset',
#    'capacity': 12000,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/504.png'}},
#  {'team': {'id': 36,
#    'name': 'Fulham',
#    'code': 'FUL',
#    'country': 'England',
#    'founded': 1879,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/36.png'},
#   'venue': {'id': 535,
#    'name': 'Craven Cottage',
#    'address': 'Stevenage Road',
#    'city': 'London',
#    'capacity': 25700,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/535.png'}},
#  {'team': {'id': 39,
#    'name': 'Wolves',
#    'code': 'WOL',
#    'country': 'England',
#    'founded': 1877,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/39.png'},
#   'venue': {'id': 600,
#    'name': 'Molineux Stadium',
#    'address': 'Waterloo Road',
#    'city': 'Wolverhampton, West Midlands',
#    'capacity': 32050,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/600.png'}},
#  {'team': {'id': 40,
#    'name': 'Liverpool',
#    'code': 'LIV',
#    'country': 'England',
#    'founded': 1892,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/40.png'},
#   'venue': {'id': 550,
#    'name': 'Anfield',
#    'address': 'Anfield Road',
#    'city': 'Liverpool',
#    'capacity': 55212,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/550.png'}},
#  {'team': {'id': 41,
#    'name': 'Southampton',
#    'code': 'SOU',
#    'country': 'England',
#    'founded': 1885,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/41.png'},
#   'venue': {'id': 585,
#    'name': "St. Mary's Stadium",
#    'address': 'Britannia Road',
#    'city': 'Southampton, Hampshire',
#    'capacity': 32689,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/585.png'}},
#  {'team': {'id': 42,
#    'name': 'Arsenal',
#    'code': 'ARS',
#    'country': 'England',
#    'founded': 1886,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/42.png'},
#   'venue': {'id': 494,
#    'name': 'Emirates Stadium',
#    'address': 'Queensland Road',
#    'city': 'London',
#    'capacity': 60383,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/494.png'}},
#  {'team': {'id': 45,
#    'name': 'Everton',
#    'code': 'EVE',
#    'country': 'England',
#    'founded': 1878,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/45.png'},
#   'venue': {'id': 8560,
#    'name': 'Goodison Park',
#    'address': 'Goodison Road',
#    'city': 'Liverpool',
#    'capacity': 40569,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/8560.png'}},
#  {'team': {'id': 46,
#    'name': 'Leicester',
#    'code': 'LEI',
#    'country': 'England',
#    'founded': 1884,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/46.png'},
#   'venue': {'id': 547,
#    'name': 'King Power Stadium',
#    'address': 'Filbert Way',
#    'city': 'Leicester, Leicestershire',
#    'capacity': 34310,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/547.png'}},
#  {'team': {'id': 47,
#    'name': 'Tottenham',
#    'code': 'TOT',
#    'country': 'England',
#    'founded': 1882,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/47.png'},
#   'venue': {'id': 593,
#    'name': 'Tottenham Hotspur Stadium',
#    'address': 'Bill Nicholson Way, 748 High Road',
#    'city': 'London',
#    'capacity': 62850,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/593.png'}},
#  {'team': {'id': 48,
#    'name': 'West Ham',
#    'code': 'WES',
#    'country': 'England',
#    'founded': 1895,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/48.png'},
#   'venue': {'id': 598,
#    'name': 'London Stadium',
#    'address': 'Marshgate Lane, Stratford',
#    'city': 'London',
#    'capacity': 62500,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/598.png'}},
#  {'team': {'id': 49,
#    'name': 'Chelsea',
#    'code': 'CHE',
#    'country': 'England',
#    'founded': 1905,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/49.png'},
#   'venue': {'id': 519,
#    'name': 'Stamford Bridge',
#    'address': 'Fulham Road',
#    'city': 'London',
#    'capacity': 41841,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/519.png'}},
#  {'team': {'id': 50,
#    'name': 'Manchester City',
#    'code': 'MAC',
#    'country': 'England',
#    'founded': 1880,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/50.png'},
#   'venue': {'id': 555,
#    'name': 'Etihad Stadium',
#    'address': 'Rowsley Street',
#    'city': 'Manchester',
#    'capacity': 55097,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/555.png'}},
#  {'team': {'id': 51,
#    'name': 'Brighton',
#    'code': 'BRI',
#    'country': 'England',
#    'founded': 1901,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/51.png'},
#   'venue': {'id': 508,
#    'name': 'The American Express Community Stadium',
#    'address': 'Village Way',
#    'city': 'Falmer, East Sussex',
#    'capacity': 31800,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/508.png'}},
#  {'team': {'id': 52,
#    'name': 'Crystal Palace',
#    'code': 'CRY',
#    'country': 'England',
#    'founded': 1905,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/52.png'},
#   'venue': {'id': 525,
#    'name': 'Selhurst Park',
#    'address': 'Holmesdale Road',
#    'city': 'London',
#    'capacity': 26309,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/525.png'}},
#  {'team': {'id': 55,
#    'name': 'Brentford',
#    'code': 'BRE',
#    'country': 'England',
#    'founded': 1889,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/55.png'},
#   'venue': {'id': 10503,
#    'name': 'Gtech Community Stadium',
#    'address': '166 Lionel Rd N, Brentford',
#    'city': 'Brentford, Middlesex',
#    'capacity': 17250,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/10503.png'}},
#  {'team': {'id': 63,
#    'name': 'Leeds',
#    'code': 'LEE',
#    'country': 'England',
#    'founded': 1919,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/63.png'},
#   'venue': {'id': 546,
#    'name': 'Elland Road',
#    'address': 'Elland Road',
#    'city': 'Leeds, West Yorkshire',
#    'capacity': 40204,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/546.png'}},
#  {'team': {'id': 65,
#    'name': 'Nottingham Forest',
#    'code': 'NOT',
#    'country': 'England',
#    'founded': 1865,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/65.png'},
#   'venue': {'id': 566,
#    'name': 'The City Ground',
#    'address': 'Pavilion Road',
#    'city': 'Nottingham, Nottinghamshire',
#    'capacity': 30576,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/566.png'}},
#  {'team': {'id': 66,
#    'name': 'Aston Villa',
#    'code': 'AST',
#    'country': 'England',
#    'founded': 1874,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/66.png'},
#   'venue': {'id': 495,
#    'name': 'Villa Park',
#    'address': 'Trinity Road',
#    'city': 'Birmingham',
#    'capacity': 42788,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/495.png'}},
#  {'team': {'id': 37,
#    'name': 'Huddersfield',
#    'code': 'HUD',
#    'country': 'England',
#    'founded': 1908,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/37.png'},
#   'venue': {'id': 543,
#    'name': "John Smith's Stadium",
#    'address': 'Stadium Way',
#    'city': 'Huddersfield, West Yorkshire',
#    'capacity': 24554,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/543.png'}},
#  {'team': {'id': 38,
#    'name': 'Watford',
#    'code': 'WAT',
#    'country': 'England',
#    'founded': 1881,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/38.png'},
#   'venue': {'id': 596,
#    'name': 'Vicarage Road',
#    'address': 'Vicarage Road',
#    'city': 'Watford',
#    'capacity': 22200,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/596.png'}},
#  {'team': {'id': 43,
#    'name': 'Cardiff',
#    'code': 'CAR',
#    'country': 'Wales',
#    'founded': 1889,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/43.png'},
#   'venue': {'id': 516,
#    'name': 'Cardiff City Stadium',
#    'address': 'Leckwith Road',
#    'city': 'Caerdydd',
#    'capacity': 33280,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/516.png'}},
#  {'team': {'id': 44,
#    'name': 'Burnley',
#    'code': 'BUR',
#    'country': 'England',
#    'founded': 1882,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/44.png'},
#   'venue': {'id': 512,
#    'name': 'Turf Moor',
#    'address': 'Harry Potts Way',
#    'city': 'Burnley',
#    'capacity': 22546,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/512.png'}},
#  {'team': {'id': 53,
#    'name': 'Reading',
#    'code': 'REA',
#    'country': 'England',
#    'founded': 1871,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/53.png'},
#   'venue': {'id': 12052,
#    'name': 'Select Car Leasing Stadium',
#    'address': 'Shooters Way / Junction 11, M4',
#    'city': 'Reading, Berkshire',
#    'capacity': 24200,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/12052.png'}},
#  {'team': {'id': 54,
#    'name': 'Birmingham',
#    'code': 'BIR',
#    'country': 'England',
#    'founded': 1875,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/54.png'},
#   'venue': {'id': 12596,
#    'name': "St Andrew's Stadium",
#    'address': 'St. Andrew&apos;s Road',
#    'city': 'Birmingham',
#    'capacity': 30009,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/12596.png'}},
#  {'team': {'id': 56,
#    'name': 'Bristol City',
#    'code': 'BRI',
#    'country': 'England',
#    'founded': 1894,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/56.png'},
#   'venue': {'id': 509,
#    'name': 'Ashton Gate',
#    'address': 'Ashton Road',
#    'city': 'Bristol',
#    'capacity': 27000,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/509.png'}},
#  {'team': {'id': 58,
#    'name': 'Millwall',
#    'code': 'MIL',
#    'country': 'England',
#    'founded': 1885,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/58.png'},
#   'venue': {'id': 559,
#    'name': 'The Den',
#    'address': 'Zampa Road, Bermondsey',
#    'city': 'London',
#    'capacity': 20146,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/559.png'}},
#  {'team': {'id': 59,
#    'name': 'Preston',
#    'code': 'PRE',
#    'country': 'England',
#    'founded': 1863,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/59.png'},
#   'venue': {'id': 574,
#    'name': 'Deepdale',
#    'address': 'Deepdale Road',
#    'city': 'Preston',
#    'capacity': 23408,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/574.png'}},
#  {'team': {'id': 60,
#    'name': 'West Brom',
#    'code': 'WES',
#    'country': 'England',
#    'founded': 1878,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/60.png'},
#   'venue': {'id': 597,
#    'name': 'The Hawthorns',
#    'address': 'Halfords Lane',
#    'city': 'West Bromwich',
#    'capacity': 28003,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/597.png'}},
#  {'team': {'id': 61,
#    'name': 'Wigan',
#    'code': 'WIG',
#    'country': 'England',
#    'founded': 1932,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/61.png'},
#   'venue': {'id': 599,
#    'name': 'DW Stadium',
#    'address': 'Robin Park, Loire Drive',
#    'city': 'Wigan',
#    'capacity': 25138,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/599.png'}},
#  {'team': {'id': 62,
#    'name': 'Sheffield Utd',
#    'code': 'SHE',
#    'country': 'England',
#    'founded': 1889,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/62.png'},
#   'venue': {'id': 581,
#    'name': 'Bramall Lane',
#    'address': 'Bramall Lane',
#    'city': 'Sheffield',
#    'capacity': 32702,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/581.png'}},
#  {'team': {'id': 64,
#    'name': 'Hull City',
#    'code': 'HUL',
#    'country': 'England',
#    'founded': 1904,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/64.png'},
#   'venue': {'id': 12051,
#    'name': 'The MKM Stadium',
#    'address': 'Walton Street / Anlaby Road',
#    'city': 'Hull',
#    'capacity': 25504,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/12051.png'}},
#  {'team': {'id': 67,
#    'name': 'Blackburn',
#    'code': 'BLA',
#    'country': 'England',
#    'founded': 1875,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/67.png'},
#   'venue': {'id': 500,
#    'name': 'Ewood Park',
#    'address': 'Nuttall Street',
#    'city': 'Blackburn, Lancashire',
#    'capacity': 31367,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/500.png'}},
#  {'team': {'id': 70,
#    'name': 'Middlesbrough',
#    'code': 'MID',
#    'country': 'England',
#    'founded': 1876,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/70.png'},
#   'venue': {'id': 558,
#    'name': 'Riverside Stadium',
#    'address': 'Dockside Road',
#    'city': 'Middlesbrough',
#    'capacity': 34988,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/558.png'}},
#  {'team': {'id': 71,
#    'name': 'Norwich',
#    'code': 'NOR',
#    'country': 'England',
#    'founded': 1902,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/71.png'},
#   'venue': {'id': 565,
#    'name': 'Carrow Road',
#    'address': 'Carrow Road',
#    'city': 'Norwich, Norfolk',
#    'capacity': 27606,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/565.png'}},
#  {'team': {'id': 72,
#    'name': 'QPR',
#    'code': 'QPR',
#    'country': 'England',
#    'founded': 1885,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/72.png'},
#   'venue': {'id': 18619,
#    'name': 'Loftus Road',
#    'address': 'South Africa Road, Shepherd&apos;s Bush',
#    'city': 'London',
#    'capacity': 18360,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/18619.png'}},
#  {'team': {'id': 73,
#    'name': 'Rotherham',
#    'code': 'ROT',
#    'country': 'England',
#    'founded': 1870,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/73.png'},
#   'venue': {'id': 578,
#    'name': 'AESSEAL New York Stadium',
#    'address': 'Don Street',
#    'city': 'Rotherham, South Yorkshire',
#    'capacity': 12021,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/578.png'}},
#  {'team': {'id': 75,
#    'name': 'Stoke City',
#    'code': 'STO',
#    'country': 'England',
#    'founded': 1868,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/75.png'},
#   'venue': {'id': 588,
#    'name': 'bet365 Stadium',
#    'address': 'Stanley Matthews Way',
#    'city': 'Stoke-on-Trent, Staffordshire',
#    'capacity': 30089,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/588.png'}},
#  {'team': {'id': 76,
#    'name': 'Swansea',
#    'code': 'SWA',
#    'country': 'Wales',
#    'founded': 1912,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/76.png'},
#   'venue': {'id': 12273,
#    'name': 'Swansea.com Stadium',
#    'address': 'Normandy Road',
#    'city': 'Swansea',
#    'capacity': 21028,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/12273.png'}},
#  {'team': {'id': 746,
#    'name': 'Sunderland',
#    'code': 'SUN',
#    'country': 'England',
#    'founded': 1879,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/746.png'},
#   'venue': {'id': 589,
#    'name': 'Stadium of Light',
#    'address': 'Millenium Way',
#    'city': 'Sunderland',
#    'capacity': 49000,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/589.png'}},
#  {'team': {'id': 1346,
#    'name': 'Coventry',
#    'code': 'COV',
#    'country': 'England',
#    'founded': 1883,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/1346.png'},
#   'venue': {'id': 11896,
#    'name': 'The Coventry Building Society Arena',
#    'address': 'Phoenix Way, Rowleys Green',
#    'city': 'Coventry, West Midlands',
#    'capacity': 32609,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/11896.png'}},
#  {'team': {'id': 1356,
#    'name': 'Blackpool',
#    'code': 'BLA',
#    'country': 'England',
#    'founded': 1887,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/1356.png'},
#   'venue': {'id': 501,
#    'name': 'Bloomfield Road',
#    'address': 'Seasiders Way',
#    'city': 'Blackpool, Lancashire',
#    'capacity': 17625,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/501.png'}},
#  {'team': {'id': 1359,
#    'name': 'Luton',
#    'code': 'LUT',
#    'country': 'England',
#    'founded': 1885,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/1359.png'},
#   'venue': {'id': 551,
#    'name': 'Kenilworth Road',
#    'address': '1 Maple Road',
#    'city': 'Luton, Bedfordshire',
#    'capacity': 10226,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/551.png'}},
#  {'team': {'id': 57,
#    'name': 'Ipswich',
#    'code': 'IPS',
#    'country': 'England',
#    'founded': 1878,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/57.png'},
#   'venue': {'id': 545,
#    'name': 'Portman Road',
# ...
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/11880.png'}},
#  {'team': {'id': 1378,
#    'name': 'Forest Green',
#    'code': 'FOR',
#    'country': 'England',
#    'founded': 1890,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/1378.png'},
#   'venue': {'id': 19201,
#    'name': 'The Bolt New Lawn',
#    'address': 'Smiths Way',
#    'city': 'Nailsworth, Gloucestershire',
#    'capacity': 5140,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/19201.png'}},
#  {'team': {'id': 1379,
#    'name': 'Lincoln',
#    'code': None,
#    'country': 'England',
#    'founded': 1884,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/1379.png'},
#   'venue': {'id': 10610,
#    'name': 'LNER Stadium',
#    'address': 'Sincil Bank',
#    'city': 'Lincoln, Lincolnshire',
#    'capacity': 10600,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/10610.png'}},
#  {'team': {'id': 1381,
#    'name': 'Tranmere',
#    'code': 'TRA',
#    'country': 'England',
#    'founded': 1884,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/1381.png'},
#   'venue': {'id': 594,
#    'name': 'Prenton Park',
#    'address': 'Prenton Road West',
#    'city': 'Birkenhead, Merseyside',
#    'capacity': 16567,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/594.png'}},
#  {'team': {'id': 1819,
#    'name': 'Barrow',
#    'code': 'BAR',
#    'country': 'England',
#    'founded': 1901,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/1819.png'},
#   'venue': {'id': 19197,
#    'name': 'SO Legal Stadium',
#    'address': 'Holker Street',
#    'city': 'Barrow-in-Furness, Cumbria',
#    'capacity': 5349,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/19197.png'}},
#  {'team': {'id': 1835,
#    'name': 'Sutton Utd',
#    'code': 'SUT',
#    'country': 'England',
#    'founded': 1898,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/1835.png'},
#   'venue': {'id': 12272,
#    'name': 'VBS Community Stadium',
#    'address': 'Gander Green Lane',
#    'city': 'Sutton, Surrey',
#    'capacity': 7032,
#    'surface': 'artificial turf',
#    'image': 'https://media-3.api-sports.io/football/venues/12272.png'}},
#  {'team': {'id': 1842,
#    'name': 'Harrogate Town',
#    'code': 'HAR',
#    'country': 'England',
#    'founded': 1914,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/1842.png'},
#   'venue': {'id': 11878,
#    'name': 'EnviroVent Stadium',
#    'address': 'Wetherby Road',
#    'city': 'Harrogate, North Yorkshire',
#    'capacity': 3800,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/11878.png'}},
#  {'team': {'id': 1844,
#    'name': 'Salford City',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/1844.png'},
#   'venue': {'id': 579,
#    'name': 'The Peninsula Stadium',
#    'address': 'Moor Lane',
#    'city': 'Salford, Greater Manchester',
#    'capacity': 5100,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/579.png'}},
#  {'team': {'id': 4686,
#    'name': 'Stockport County',
#    'code': 'STO',
#    'country': 'England',
#    'founded': 1883,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/4686.png'},
#   'venue': {'id': 3535,
#    'name': 'Edgeley Park',
#    'address': 'Hardcastle Road, Edgeley',
#    'city': 'Stockport, Greater Manchester',
#    'capacity': 10852,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/3535.png'}},
#  {'team': {'id': 7189,
#    'name': 'Arsenal U21',
#    'code': 'ARS',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7189.png'},
#   'venue': {'id': 5201,
#    'name': 'Colney Training Centre',
#    'address': 'Hethersett Lane',
#    'city': 'Colney, Norfolk',
#    'capacity': 1000,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5201.png'}},
#  {'team': {'id': 7190,
#    'name': 'Aston Villa U21',
#    'code': 'AST',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7190.png'},
#   'venue': {'id': 5202,
#    'name': 'Bodymoor Heath Training Ground',
#    'address': 'Bond Street, Nr. Tamworth',
#    'city': 'Bodymoor Heath, Warwickshire',
#    'capacity': 1000,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5202.png'}},
#  {'team': {'id': 7191,
#    'name': 'Brighton U21',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7191.png'},
#   'venue': {'id': None,
#    'name': None,
#    'address': None,
#    'city': None,
#    'capacity': None,
#    'surface': None,
#    'image': None}},
#  {'team': {'id': 7192,
#    'name': 'Chelsea U21',
#    'code': 'CHE',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7192.png'},
#   'venue': {'id': 507,
#    'name': 'Griffin Park',
#    'address': 'Braemar Road, London Borough of Hounslow',
#    'city': 'Brentford, Middlesex',
#    'capacity': 12763,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/507.png'}},
#  {'team': {'id': 7193,
#    'name': 'Everton U21',
#    'code': 'EVE',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7193.png'},
#   'venue': {'id': 2694,
#    'name': 'Haig Avenue',
#    'address': 'Haig Avenue',
#    'city': 'Southport, Merseyside',
#    'capacity': 6008,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/2694.png'}},
#  {'team': {'id': 7195,
#    'name': 'Leicester City U21',
#    'code': 'LEI',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7195.png'},
#   'venue': {'id': None,
#    'name': None,
#    'address': None,
#    'city': None,
#    'capacity': None,
#    'surface': None,
#    'image': None}},
#  {'team': {'id': 7196,
#    'name': 'Liverpool U21',
#    'code': 'LIV',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7196.png'},
#   'venue': {'id': 5206,
#    'name': 'Liverpool’s Academy Ground',
#    'address': 'The Liverpool Way, Kirkby',
#    'city': 'Knowsley, Merseyside',
#    'capacity': 1000,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/5206.png'}},
#  {'team': {'id': 7197,
#    'name': 'Manchester City U21',
#    'code': 'MAC',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7197.png'},
#   'venue': {'id': 3543,
#    'name': 'Ewen Fields',
#    'address': 'Grange Road',
#    'city': 'Hyde, Cheshire',
#    'capacity': 4100,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/3543.png'}},
#  {'team': {'id': 7198,
#    'name': 'Manchester United U21',
#    'code': 'MUN',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7198.png'},
#   'venue': {'id': 3549,
#    'name': 'The J. Davidson Stadium',
#    'address': 'Moss Lane',
#    'city': 'Altrincham, Cheshire',
#    'capacity': 6085,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/3549.png'}},
#  {'team': {'id': 7199,
#    'name': 'Newcastle United U21',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/7199.png'},
#   'venue': {'id': None,
#    'name': None,
#    'address': None,
#    'city': None,
#    'capacity': None,
#    'surface': None,
#    'image': None}},
#  {'team': {'id': 7201,
#    'name': 'Southampton U21',
#    'code': 'SOU',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7201.png'},
#   'venue': {'id': 5208,
#    'name': 'Staplewood Training Ground',
#    'address': 'Long Lane, Marchwood',
#    'city': 'Southampton, Hampshire',
#    'capacity': 3000,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/5208.png'}},
#  {'team': {'id': 7202,
#    'name': 'Tottenham Hotspur U21',
#    'code': 'TOT',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7202.png'},
#   'venue': {'id': None,
#    'name': None,
#    'address': None,
#    'city': None,
#    'capacity': None,
#    'surface': None,
#    'image': None}},
#  {'team': {'id': 7203,
#    'name': 'West Ham United U21',
#    'code': 'WES',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/7203.png'},
#   'venue': {'id': None,
#    'name': None,
#    'address': None,
#    'city': None,
#    'capacity': None,
#    'surface': None,
#    'image': None}},
#  {'team': {'id': 7204,
#    'name': 'Wolves U21',
#    'code': 'WOL',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/7204.png'},
#   'venue': {'id': None,
#    'name': None,
#    'address': None,
#    'city': None,
#    'capacity': None,
#    'surface': None,
#    'image': None}},
#  {'team': {'id': 14430,
#    'name': 'Leeds United U21',
#    'code': None,
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/14430.png'},
#   'venue': {'id': None,
#    'name': None,
#    'address': None,
#    'city': None,
#    'capacity': None,
#    'surface': None,
#    'image': None}},
#  {'team': {'id': 17000,
#    'name': 'Crystal Palace U21',
#    'code': 'CRY',
#    'country': 'England',
#    'founded': None,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/17000.png'},
#   'venue': {'id': 11883,
#    'name': 'Selhurst Park',
#    'address': 'Holmesdale Road',
#    'city': 'London',
#    'capacity': 26309,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/11883.png'}},
#  {'team': {'id': 1340,
#    'name': 'Scunthorpe',
#    'code': 'SCU',
#    'country': 'England',
#    'founded': 1899,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/1340.png'},
#   'venue': {'id': 18857,
#    'name': 'Glanford Park',
#    'address': 'Doncaster Road',
#    'city': 'Scunthorpe',
#    'capacity': 9088,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/18857.png'}},
#  {'team': {'id': 1341,
#    'name': 'Southend',
#    'code': 'SOU',
#    'country': 'England',
#    'founded': 1906,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/1341.png'},
#   'venue': {'id': 586,
#    'name': 'Roots Hall',
#    'address': 'Victoria Avenue, Prittlewell',
#    'city': 'Southend-on-Sea, Essex',
#    'capacity': 12392,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/586.png'}},
#  {'team': {'id': 1345,
#    'name': 'Chesterfield',
#    'code': 'CHE',
#    'country': 'England',
#    'founded': 1867,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/1345.png'},
#   'venue': {'id': 11895,
#    'name': 'Technique Stadium',
#    'address': '1866 Sheffield Road, Whittington Moor',
#    'city': 'Chesterfield, Derbyshire',
#    'capacity': 10338,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/11895.png'}},
#  {'team': {'id': 1349,
#    'name': 'Oldham',
#    'code': 'OLD',
#    'country': 'England',
#    'founded': 1895,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/1349.png'},
#   'venue': {'id': 568,
#    'name': 'Boundary Park',
#    'address': 'Furtherwood Road, Royton',
#    'city': 'Oldham, Greater Manchester',
#    'capacity': 10638,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/568.png'}},
#  {'team': {'id': 1369,
#    'name': 'Barnet',
#    'code': 'BAR',
#    'country': 'England',
#    'founded': 1888,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/1369.png'},
#   'venue': {'id': 496,
#    'name': 'The Hive Stadium',
#    'address': 'Camrose Avenue, Canons Park, Edgware',
#    'city': 'London',
#    'capacity': 6418,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/496.png'}},
#  {'team': {'id': 1376,
#    'name': 'Notts County',
#    'code': 'NOT',
#    'country': 'England',
#    'founded': 1862,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/1376.png'},
#   'venue': {'id': 567,
#    'name': 'Meadow Lane',
#    'address': 'Meadow Lane',
#    'city': 'Nottingham, Nottinghamshire',
#    'capacity': 19588,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/567.png'}},
#  {'team': {'id': 1377,
#    'name': 'Yeovil Town',
#    'code': 'YEO',
#    'country': 'England',
#    'founded': 1895,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/1377.png'},
#   'venue': {'id': 603,
#    'name': 'Huish Park Stadium',
#    'address': 'Lufton Way, Lufton',
#    'city': 'Yeovil, Somerset',
#    'capacity': 9665,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/603.png'}},
#  {'team': {'id': 1380,
#    'name': 'Macclesfield',
#    'code': 'MAC',
#    'country': 'England',
#    'founded': 2020,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/1380.png'},
#   'venue': {'id': 12213,
#    'name': 'The Leasing.com Stadium',
#    'address': 'London Road',
#    'city': 'Macclesfield, Cheshire',
#    'capacity': 6355,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/12213.png'}},
#  {'team': {'id': 1818,
#    'name': 'Aldershot Town',
#    'code': 'ALD',
#    'country': 'England',
#    'founded': 1992,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/1818.png'},
#   'venue': {'id': 493,
#    'name': 'Electrical Services Stadium',
#    'address': 'High Street',
#    'city': 'Aldershot, Hampshire',
#    'capacity': 7100,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/493.png'}},
#  {'team': {'id': 1820,
#    'name': 'Chester',
#    'code': 'CHE',
#    'country': 'England',
#    'founded': 2010,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/1820.png'},
#   'venue': {'id': 2690,
#    'name': 'Lookers Vauxhall Stadium',
#    'address': 'Bumpers Lane',
#    'city': 'Chester, Cheshire',
#    'capacity': 5376,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/2690.png'}},
#  {'team': {'id': 1821,
#    'name': 'Dagenham & Redbridge',
#    'code': 'DAG',
#    'country': 'England',
#    'founded': 1992,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/1821.png'},
#   'venue': {'id': 526,
#    'name': 'Chigwell Construction Stadium',
#    'address': 'Victoria Road',
#    'city': 'Dagenham, Essex',
#    'capacity': 6078,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/526.png'}},
#  {'team': {'id': 1822,
#    'name': 'Eastleigh',
#    'code': 'EAS',
#    'country': 'England',
#    'founded': 1949,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/1822.png'},
#   'venue': {'id': 530,
#    'name': 'Silverlake Stadium',
#    'address': 'Stoneham Lane',
#    'city': 'Eastleigh, Hampshire',
#    'capacity': 5250,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/530.png'}},
#  {'team': {'id': 1823,
#    'name': 'Gateshead',
#    'code': 'GAT',
#    'country': 'England',
#    'founded': 1889,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/1823.png'},
#   'venue': {'id': 536,
#    'name': 'Gateshead International Stadium',
#    'address': 'Neilson Road',
#    'city': 'Gateshead, Tyne and Wear',
#    'capacity': 11750,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/536.png'}},
#  ...]

# %%
type(response.json()['response'])
# Out:
# list

# %%
url = "https://api-football-v1.p.rapidapi.com/v3/teams"

querystring = {"league":"39","season":"2022"}

headers = {
	"X-RapidAPI-Key": "95d1d0071fmsh61e56ba2bd00280p11af1ajsna4e07526c0e4",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
response.json()['response']
# Out:
# [{'team': {'id': 33,
#    'name': 'Manchester United',
#    'code': 'MUN',
#    'country': 'England',
#    'founded': 1878,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/33.png'},
#   'venue': {'id': 556,
#    'name': 'Old Trafford',
#    'address': 'Sir Matt Busby Way',
#    'city': 'Manchester',
#    'capacity': 76212,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/556.png'}},
#  {'team': {'id': 34,
#    'name': 'Newcastle',
#    'code': 'NEW',
#    'country': 'England',
#    'founded': 1892,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/34.png'},
#   'venue': {'id': 562,
#    'name': "St. James' Park",
#    'address': 'St. James&apos; Street',
#    'city': 'Newcastle upon Tyne',
#    'capacity': 52389,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/562.png'}},
#  {'team': {'id': 35,
#    'name': 'Bournemouth',
#    'code': 'BOU',
#    'country': 'England',
#    'founded': 1899,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/35.png'},
#   'venue': {'id': 504,
#    'name': 'Vitality Stadium',
#    'address': 'Dean Court, Kings Park',
#    'city': 'Bournemouth, Dorset',
#    'capacity': 12000,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/504.png'}},
#  {'team': {'id': 36,
#    'name': 'Fulham',
#    'code': 'FUL',
#    'country': 'England',
#    'founded': 1879,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/36.png'},
#   'venue': {'id': 535,
#    'name': 'Craven Cottage',
#    'address': 'Stevenage Road',
#    'city': 'London',
#    'capacity': 25700,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/535.png'}},
#  {'team': {'id': 39,
#    'name': 'Wolves',
#    'code': 'WOL',
#    'country': 'England',
#    'founded': 1877,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/39.png'},
#   'venue': {'id': 600,
#    'name': 'Molineux Stadium',
#    'address': 'Waterloo Road',
#    'city': 'Wolverhampton, West Midlands',
#    'capacity': 32050,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/600.png'}},
#  {'team': {'id': 40,
#    'name': 'Liverpool',
#    'code': 'LIV',
#    'country': 'England',
#    'founded': 1892,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/40.png'},
#   'venue': {'id': 550,
#    'name': 'Anfield',
#    'address': 'Anfield Road',
#    'city': 'Liverpool',
#    'capacity': 55212,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/550.png'}},
#  {'team': {'id': 41,
#    'name': 'Southampton',
#    'code': 'SOU',
#    'country': 'England',
#    'founded': 1885,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/41.png'},
#   'venue': {'id': 585,
#    'name': "St. Mary's Stadium",
#    'address': 'Britannia Road',
#    'city': 'Southampton, Hampshire',
#    'capacity': 32689,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/585.png'}},
#  {'team': {'id': 42,
#    'name': 'Arsenal',
#    'code': 'ARS',
#    'country': 'England',
#    'founded': 1886,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/42.png'},
#   'venue': {'id': 494,
#    'name': 'Emirates Stadium',
#    'address': 'Queensland Road',
#    'city': 'London',
#    'capacity': 60383,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/494.png'}},
#  {'team': {'id': 45,
#    'name': 'Everton',
#    'code': 'EVE',
#    'country': 'England',
#    'founded': 1878,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/45.png'},
#   'venue': {'id': 8560,
#    'name': 'Goodison Park',
#    'address': 'Goodison Road',
#    'city': 'Liverpool',
#    'capacity': 40569,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/8560.png'}},
#  {'team': {'id': 46,
#    'name': 'Leicester',
#    'code': 'LEI',
#    'country': 'England',
#    'founded': 1884,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/46.png'},
#   'venue': {'id': 547,
#    'name': 'King Power Stadium',
#    'address': 'Filbert Way',
#    'city': 'Leicester, Leicestershire',
#    'capacity': 34310,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/547.png'}},
#  {'team': {'id': 47,
#    'name': 'Tottenham',
#    'code': 'TOT',
#    'country': 'England',
#    'founded': 1882,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/47.png'},
#   'venue': {'id': 593,
#    'name': 'Tottenham Hotspur Stadium',
#    'address': 'Bill Nicholson Way, 748 High Road',
#    'city': 'London',
#    'capacity': 62850,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/593.png'}},
#  {'team': {'id': 48,
#    'name': 'West Ham',
#    'code': 'WES',
#    'country': 'England',
#    'founded': 1895,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/48.png'},
#   'venue': {'id': 598,
#    'name': 'London Stadium',
#    'address': 'Marshgate Lane, Stratford',
#    'city': 'London',
#    'capacity': 62500,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/598.png'}},
#  {'team': {'id': 49,
#    'name': 'Chelsea',
#    'code': 'CHE',
#    'country': 'England',
#    'founded': 1905,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/49.png'},
#   'venue': {'id': 519,
#    'name': 'Stamford Bridge',
#    'address': 'Fulham Road',
#    'city': 'London',
#    'capacity': 41841,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/519.png'}},
#  {'team': {'id': 50,
#    'name': 'Manchester City',
#    'code': 'MAC',
#    'country': 'England',
#    'founded': 1880,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/50.png'},
#   'venue': {'id': 555,
#    'name': 'Etihad Stadium',
#    'address': 'Rowsley Street',
#    'city': 'Manchester',
#    'capacity': 55097,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/555.png'}},
#  {'team': {'id': 51,
#    'name': 'Brighton',
#    'code': 'BRI',
#    'country': 'England',
#    'founded': 1901,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/51.png'},
#   'venue': {'id': 508,
#    'name': 'The American Express Community Stadium',
#    'address': 'Village Way',
#    'city': 'Falmer, East Sussex',
#    'capacity': 31800,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/508.png'}},
#  {'team': {'id': 52,
#    'name': 'Crystal Palace',
#    'code': 'CRY',
#    'country': 'England',
#    'founded': 1905,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/52.png'},
#   'venue': {'id': 525,
#    'name': 'Selhurst Park',
#    'address': 'Holmesdale Road',
#    'city': 'London',
#    'capacity': 26309,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/525.png'}},
#  {'team': {'id': 55,
#    'name': 'Brentford',
#    'code': 'BRE',
#    'country': 'England',
#    'founded': 1889,
#    'national': False,
#    'logo': 'https://media-1.api-sports.io/football/teams/55.png'},
#   'venue': {'id': 10503,
#    'name': 'Gtech Community Stadium',
#    'address': '166 Lionel Rd N, Brentford',
#    'city': 'Brentford, Middlesex',
#    'capacity': 17250,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/10503.png'}},
#  {'team': {'id': 63,
#    'name': 'Leeds',
#    'code': 'LEE',
#    'country': 'England',
#    'founded': 1919,
#    'national': False,
#    'logo': 'https://media-3.api-sports.io/football/teams/63.png'},
#   'venue': {'id': 546,
#    'name': 'Elland Road',
#    'address': 'Elland Road',
#    'city': 'Leeds, West Yorkshire',
#    'capacity': 40204,
#    'surface': 'grass',
#    'image': 'https://media-2.api-sports.io/football/venues/546.png'}},
#  {'team': {'id': 65,
#    'name': 'Nottingham Forest',
#    'code': 'NOT',
#    'country': 'England',
#    'founded': 1865,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/65.png'},
#   'venue': {'id': 566,
#    'name': 'The City Ground',
#    'address': 'Pavilion Road',
#    'city': 'Nottingham, Nottinghamshire',
#    'capacity': 30576,
#    'surface': 'grass',
#    'image': 'https://media-3.api-sports.io/football/venues/566.png'}},
#  {'team': {'id': 66,
#    'name': 'Aston Villa',
#    'code': 'AST',
#    'country': 'England',
#    'founded': 1874,
#    'national': False,
#    'logo': 'https://media-2.api-sports.io/football/teams/66.png'},
#   'venue': {'id': 495,
#    'name': 'Villa Park',
#    'address': 'Trinity Road',
#    'city': 'Birmingham',
#    'capacity': 42788,
#    'surface': 'grass',
#    'image': 'https://media-1.api-sports.io/football/venues/495.png'}}]

# %%
url = "https://api-football-v1.p.rapidapi.com/v3/teams"

querystring = {"season":"2022","country":"England"}

headers = {
	"X-RapidAPI-Key": "95d1d0071fmsh61e56ba2bd00280p11af1ajsna4e07526c0e4",
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

# %%
response.json()
# Out:
# {'get': 'teams',
#  'parameters': {'country': 'England', 'season': '2022'},
#  'errors': {'league': 'The League field is required.'},
#  'results': 0,
#  'paging': {'current': 1, 'total': 1},
#  'response': []}
